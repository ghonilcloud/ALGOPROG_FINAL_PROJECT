# %% [markdown]
# <a href="https://colab.research.google.com/github/ghonilcloud/ALGOPROG_FINAL_PROJECT/blob/main/OnealWaseem_2702342842_Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate
import re
from sklearn.impute import SimpleImputer

# %%
df1 = pd.read_csv('/content/df1.csv')
df2 = pd.read_csv('/content/df2.csv')
df1_copy = df1
df2_copy = df2

# %%
df1.head()
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  5YJSA1E22K       King  Seattle    WA      98112.0        2019   TESLA
# 1  3MW39FS05R     Yakima   Zillah    WA      98953.0        2024     BMW
# 2  1N4AZ0CP0F       King     Kent    WA      98031.0        2015  NISSAN
# 3  5YJSA1H20F  Snohomish  Bothell    WA      98012.0        2015   TESLA
# 4  JTMAB3FV1N     Yakima   Yakima    WA      98908.0        2022  TOYOTA
#
#         Model                   Electric Vehicle Type  \
# 0     MODEL S          Battery Electric Vehicle (BEV)
# 1        330E  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     MODEL S          Battery Electric Vehicle (BEV)
# 4  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             270
# ...

# %%
df2.head()
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year     Make  \
# 0  KM8K33AGXL      King   Seattle    WA      98103.0        2020  HYUNDAI
# 1  1C4RJYB61N      King   Bothell    WA      98011.0        2022     JEEP
# 2  1C4RJYD61P    Yakima    Yakima    WA      98908.0        2023     JEEP
# 3  5YJ3E1EA7J      King  Kirkland    WA      98034.0        2018    TESLA
# 4  WBY7Z8C5XJ  Thurston   Olympia    WA      98501.0        2018      BMW
#
#             Model                   Electric Vehicle Type  \
# 0            KONA          Battery Electric Vehicle (BEV)
# 1  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 3         MODEL 3          Battery Electric Vehicle (BEV)
# 4              I3  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             258
# ...

# %%
df1.tail()
# Out:
#         VIN (1-10)        County       City State  Postal Code  Model Year  \
# 191402  5YJ3E1EA0K        Pierce     Sumner    WA      98390.0        2019
# 191403  JN1BF0BA7P        Pierce   Wilkeson    WA      98396.0        2023
# 191404  7SAYGDEE4R          King  Fall City    WA      98024.0        2024
# 191405  7SAXCBE65N  Grays Harbor   Aberdeen    WA      98520.0        2022
# 191406  7SAYGAEEXP        Benton   Richland    WA      99352.0        2023
#
#           Make    Model           Electric Vehicle Type  \
# 191402   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 191403  NISSAN    ARIYA  Battery Electric Vehicle (BEV)
# 191404   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 191405   TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 191406   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 191402            Clean Alternative Fuel Vehicle Eligible             220
# ...

# %%
df2.tail()
# Out:
#         VIN (1-10)        County               City State  Postal Code  \
# 150477  WBY43AW05P  Grays Harbor          Montesano    WA      98563.0
# 150478  5YJ3E1EB7P          King            Seattle    WA      98104.0
# 150479  5YJYGDEEXM          King            Seattle    WA      98109.0
# 150480  5UXTA6C08P     Snohomish  Mountlake Terrace    WA      98043.0
# 150481  7SAYGDEF8N        Skagit       Mount Vernon    WA      98273.0
#
#         Model Year   Make    Model                   Electric Vehicle Type  \
# 150477        2023    BMW       I4          Battery Electric Vehicle (BEV)
# 150478        2023  TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 150479        2021  TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 150480        2023    BMW       X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 150481        2022  TESLA  MODEL Y          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %%
df1.info()
df1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191407 entries, 0 to 191406
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         191407 non-null  object
#  1   County                                             191403 non-null  object
#  2   City                                               191403 non-null  object
#  3   State                                              191407 non-null  object
#  4   Postal Code                                        191403 non-null  float64
#  5   Model Year                                         191407 non-null  int64
#  6   Make                                               191407 non-null  object
#  7   Model                                              191407 non-null  object
# ...

# %%
df2.info()
df2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150482 entries, 0 to 150481
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         150482 non-null  object
#  1   County                                             150479 non-null  object
#  2   City                                               150479 non-null  object
#  3   State                                              150482 non-null  object
#  4   Postal Code                                        150479 non-null  float64
#  5   Model Year                                         150482 non-null  int64
#  6   Make                                               150482 non-null  object
#  7   Model                                              150482 non-null  object
# ...

# %%
df_merged = df1.merge(df2, on='VIN (1-10)', how='inner')
df_merged

# %%
df_concat = pd.concat([df1, df2],
            axis = 1)
df_concat
# Out:
#         VIN (1-10)        County       City State  Postal Code  Model Year  \
# 0       5YJSA1E22K          King    Seattle    WA      98112.0        2019
# 1       3MW39FS05R        Yakima     Zillah    WA      98953.0        2024
# 2       1N4AZ0CP0F          King       Kent    WA      98031.0        2015
# 3       5YJSA1H20F     Snohomish    Bothell    WA      98012.0        2015
# 4       JTMAB3FV1N        Yakima     Yakima    WA      98908.0        2022
# ...            ...           ...        ...   ...          ...         ...
# 191402  5YJ3E1EA0K        Pierce     Sumner    WA      98390.0        2019
# 191403  JN1BF0BA7P        Pierce   Wilkeson    WA      98396.0        2023
# 191404  7SAYGDEE4R          King  Fall City    WA      98024.0        2024
# 191405  7SAXCBE65N  Grays Harbor   Aberdeen    WA      98520.0        2022
# 191406  7SAYGAEEXP        Benton   Richland    WA      99352.0        2023
#
# ...

# %%
missing_values1 = df1.isnull().sum()
print(missing_values1)

missing_rows1 = df1[df1.isnull().any(axis=1)]
display(missing_rows1)
# Out:
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 414
# DOL Vehicle ID                                         0
# Vehicle Location                                       8
# Electric Utility                                       4
# ...

# %%
missing_values2 = df2.isnull().sum()
print(missing_values2)

missing_rows2 = df2[df2.isnull().any(axis=1)]
display(missing_rows2)
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 341
# DOL Vehicle ID                                         0
# Vehicle Location                                       7
# Electric Utility                                       3
# ...

# %%
df1 = df1.dropna()
missing_rows3 = df1[df1.isnull().any(axis=1)]
display(missing_rows3)
# Out:
# Empty DataFrame
# Columns: [VIN (1-10), County, City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, 2020 Census Tract]
# Index: []

# %%
df2 = df2.dropna()
missing_rows4 = df2[df2.isnull().any(axis=1)]
display(missing_rows4)
# Out:
# Empty DataFrame
# Columns: [VIN (1-10), County, City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, 2020 Census Tract]
# Index: []

# %%
df1_filled = df1.fillna('-')
filled_rows1 = df1_filled[df1_filled.isnull().any(axis=1)]
display(filled_rows1)
# Out:
# Empty DataFrame
# Columns: [VIN (1-10), County, City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, 2020 Census Tract]
# Index: []

# %%
df2_filled  = df2.fillna('-')
filled_rows2 = df2_filled[df2_filled.isnull().any(axis=1)]
display(filled_rows2)
# Out:
# Empty DataFrame
# Columns: [VIN (1-10), County, City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, 2020 Census Tract]
# Index: []

# %%
columns_to_clean = ['Postal Code', 'Model Year', 'Electric Range', 'Base MSRP', 'Legislative District', 'DOL Vehicle ID']

for col in columns_to_clean:
    df1[col] = df1[col].apply(lambda x: re.sub(r'[^0-9]+', '', str(x)))
# Out:
# <ipython-input-16-f96db290fdb7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].apply(lambda x: re.sub(r'[^0-9]+', '', str(x)))

# %%
columns_to_clean = ['Postal Code', 'Model Year', 'Electric Range', 'Base MSRP', 'Legislative District', 'DOL Vehicle ID']

for col in columns_to_clean:
    df2[col] = df2[col].apply(lambda x: re.sub(r'[^0-9]+', '', str(x)))
# Out:
# <ipython-input-17-4a6eecfc7c45>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[col] = df2[col].apply(lambda x: re.sub(r'[^0-9]+', '', str(x)))

# %%
columns_to_clean = ['Postal Code_x', 'Postal Code_y', 'Model Year_x','Model Year_y', 'Electric Range_x','Electric Range_y' , 'Base MSRP_x','Base MSRP_y', 'Legislative District_x','Legislative District_y', 'DOL Vehicle ID_x','DOL Vehicle ID_y']

for col in columns_to_clean:
    df_merged[col] = df_merged[col].apply(lambda x: re.sub(r'[^0-9]+', '', str(x)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b0034653d418> in <cell line: 3>()
#       2
#       3 for col in columns_to_clean:
# ----> 4     df_merged[col] = df_merged[col].apply(lambda x: re.sub(r'[^0-9]+', '', str(x)))
#
# NameError: name 'df_merged' is not defined

# %%
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", 1000)
pd.set_option("display.float_format", "{:.2f}".format)
pd.set_option("display.max_colwidth", 90)

# %%
pd.reset_option("all")
# Out:
# <ipython-input-20-815ccf52250a>:1: FutureWarning: data_manager option is deprecated and will be removed in a future version. Only the BlockManager will be available.
#   pd.reset_option("all")
# <ipython-input-20-815ccf52250a>:1: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option("all")

# %%
df1.rename(columns={'County': 'County Name', 'City': 'City Name', }, inplace=True)
display(df1)
# Out:
#         VIN (1-10)   County Name  City Name State  Postal Code  Model Year  \
# 0       5YJSA1E22K          King    Seattle    WA      98112.0        2019
# 1       3MW39FS05R        Yakima     Zillah    WA      98953.0        2024
# 2       1N4AZ0CP0F          King       Kent    WA      98031.0        2015
# 3       5YJSA1H20F     Snohomish    Bothell    WA      98012.0        2015
# 4       JTMAB3FV1N        Yakima     Yakima    WA      98908.0        2022
# ...            ...           ...        ...   ...          ...         ...
# 191402  5YJ3E1EA0K        Pierce     Sumner    WA      98390.0        2019
# 191403  JN1BF0BA7P        Pierce   Wilkeson    WA      98396.0        2023
# 191404  7SAYGDEE4R          King  Fall City    WA      98024.0        2024
# 191405  7SAXCBE65N  Grays Harbor   Aberdeen    WA      98520.0        2022
# 191406  7SAYGAEEXP        Benton   Richland    WA      99352.0        2023
#
# ...

# %%
df2.rename(columns={'County': 'County Name', 'City': 'City Name', }, inplace=True)
display(df2)
# Out:
#         VIN (1-10)   County Name          City Name State  Postal Code  \
# 0       KM8K33AGXL          King            Seattle    WA      98103.0
# 1       1C4RJYB61N          King            Bothell    WA      98011.0
# 2       1C4RJYD61P        Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA7J          King           Kirkland    WA      98034.0
# 4       WBY7Z8C5XJ      Thurston            Olympia    WA      98501.0
# ...            ...           ...                ...   ...          ...
# 150477  WBY43AW05P  Grays Harbor          Montesano    WA      98563.0
# 150478  5YJ3E1EB7P          King            Seattle    WA      98104.0
# 150479  5YJYGDEEXM          King            Seattle    WA      98109.0
# 150480  5UXTA6C08P     Snohomish  Mountlake Terrace    WA      98043.0
# 150481  7SAYGDEF8N        Skagit       Mount Vernon    WA      98273.0
#
#         Model Year     Make           Model  \
# 0             2020  HYUNDAI            KONA
# ...

# %%
df_merged.rename(columns={'County Name_x': 'County Name', 'City Name_x': 'City Name', }, inplace=True)
display(df_merged)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-94828bc421b2> in <cell line: 1>()
# ----> 1 df_merged.rename(columns={'County Name_x': 'County Name', 'City Name_x': 'City Name', }, inplace=True)
#       2 display(df_merged)
#
# NameError: name 'df_merged' is not defined

# %%
indexed_df1 = df1.set_index(['City Name'])
display(indexed_df1)
# Out:
#            VIN (1-10)   County Name State  Postal Code  Model Year    Make  \
# City Name
# Seattle    5YJSA1E22K          King    WA      98112.0        2019   TESLA
# Zillah     3MW39FS05R        Yakima    WA      98953.0        2024     BMW
# Kent       1N4AZ0CP0F          King    WA      98031.0        2015  NISSAN
# Bothell    5YJSA1H20F     Snohomish    WA      98012.0        2015   TESLA
# Yakima     JTMAB3FV1N        Yakima    WA      98908.0        2022  TOYOTA
# ...               ...           ...   ...          ...         ...     ...
# Sumner     5YJ3E1EA0K        Pierce    WA      98390.0        2019   TESLA
# Wilkeson   JN1BF0BA7P        Pierce    WA      98396.0        2023  NISSAN
# Fall City  7SAYGDEE4R          King    WA      98024.0        2024   TESLA
# Aberdeen   7SAXCBE65N  Grays Harbor    WA      98520.0        2022   TESLA
# Richland   7SAYGAEEXP        Benton    WA      99352.0        2023   TESLA
#
# ...

# %%
indexed_df2 = df2.set_index(['City Name'])
display(indexed_df2)
# Out:
#                    VIN (1-10)   County Name State  Postal Code  Model Year  \
# City Name
# Seattle            KM8K33AGXL          King    WA      98103.0        2020
# Bothell            1C4RJYB61N          King    WA      98011.0        2022
# Yakima             1C4RJYD61P        Yakima    WA      98908.0        2023
# Kirkland           5YJ3E1EA7J          King    WA      98034.0        2018
# Olympia            WBY7Z8C5XJ      Thurston    WA      98501.0        2018
# ...                       ...           ...   ...          ...         ...
# Montesano          WBY43AW05P  Grays Harbor    WA      98563.0        2023
# Seattle            5YJ3E1EB7P          King    WA      98104.0        2023
# Seattle            5YJYGDEEXM          King    WA      98109.0        2021
# Mountlake Terrace  5UXTA6C08P     Snohomish    WA      98043.0        2023
# Mount Vernon       7SAYGDEF8N        Skagit    WA      98273.0        2022
#
#                       Make           Model  \
# ...

# %%
indexed_df_merged = df_merged.set_index(['City Name'])
display(indexed_df_merged)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-fdd20c32f64a> in <cell line: 1>()
# ----> 1 indexed_df_merged = df_merged.set_index(['City Name'])
#       2 display(indexed_df_merged)
#
# NameError: name 'df_merged' is not defined

# %%
id_vars = ['VIN (1-10)', 'County Name', 'City Name', 'State', 'Postal Code',
           'Legislative District', '2020 Census Tract', 'DOL Vehicle ID', 'Vehicle Location']
value_vars = ['Make', 'Model']
var_name = 'Car ID Type'
value_name = 'Car ID'

melted_df1 = pd.melt(df1, id_vars=id_vars, value_vars=value_vars,
                     var_name=var_name, value_name=value_name)

display(melted_df1)
# Out:
#         VIN (1-10)   County Name  City Name State  Postal Code  \
# 0       5YJSA1E22K          King    Seattle    WA      98112.0
# 1       3MW39FS05R        Yakima     Zillah    WA      98953.0
# 2       1N4AZ0CP0F          King       Kent    WA      98031.0
# 3       5YJSA1H20F     Snohomish    Bothell    WA      98012.0
# 4       JTMAB3FV1N        Yakima     Yakima    WA      98908.0
# ...            ...           ...        ...   ...          ...
# 382809  5YJ3E1EA0K        Pierce     Sumner    WA      98390.0
# 382810  JN1BF0BA7P        Pierce   Wilkeson    WA      98396.0
# 382811  7SAYGDEE4R          King  Fall City    WA      98024.0
# 382812  7SAXCBE65N  Grays Harbor   Aberdeen    WA      98520.0
# 382813  7SAYGAEEXP        Benton   Richland    WA      99352.0
#
#         Legislative District  2020 Census Tract  DOL Vehicle ID  \
# 0                       43.0       5.303301e+10       202233958
# 1                       15.0       5.307700e+10       264425178
# ...

# %%
id_vars = ['VIN (1-10)', 'County Name', 'City Name', 'State', 'Postal Code',
           'Legislative District', '2020 Census Tract', 'DOL Vehicle ID', 'Vehicle Location']
value_vars = ['Make', 'Model']
var_name = 'Car ID Type'
value_name = 'Car ID'

melted_df2 = pd.melt(df1, id_vars=id_vars, value_vars=value_vars,
                     var_name=var_name, value_name=value_name)

display(melted_df2)
# Out:
#         VIN (1-10)   County Name  City Name State  Postal Code  \
# 0       5YJSA1E22K          King    Seattle    WA      98112.0
# 1       3MW39FS05R        Yakima     Zillah    WA      98953.0
# 2       1N4AZ0CP0F          King       Kent    WA      98031.0
# 3       5YJSA1H20F     Snohomish    Bothell    WA      98012.0
# 4       JTMAB3FV1N        Yakima     Yakima    WA      98908.0
# ...            ...           ...        ...   ...          ...
# 382809  5YJ3E1EA0K        Pierce     Sumner    WA      98390.0
# 382810  JN1BF0BA7P        Pierce   Wilkeson    WA      98396.0
# 382811  7SAYGDEE4R          King  Fall City    WA      98024.0
# 382812  7SAXCBE65N  Grays Harbor   Aberdeen    WA      98520.0
# 382813  7SAYGAEEXP        Benton   Richland    WA      99352.0
#
#         Legislative District  2020 Census Tract  DOL Vehicle ID  \
# 0                       43.0       5.303301e+10       202233958
# 1                       15.0       5.307700e+10       264425178
# ...

# %%
df1.groupby('City Name')['Electric Range'].median()
# Out:
# City Name
# Aberdeen                    25.0
# Aberdeen Proving Ground      0.0
# Acme                        19.0
# Addy                       154.0
# Adna                         0.0
#                            ...
# Yakima                      19.0
# Yarrow Point                16.0
# Yelm                         0.0
# Yorktown                     0.0
# Zillah                       0.0
# Name: Electric Range, Length: 744, dtype: float64

# %%
df2.groupby('City Name')['Electric Range'].median()
# Out:
# City Name
# Aberdeen          26.0
# Acme              26.0
# Addy              12.5
# Airway Heights    36.5
# Alameda            0.0
#                   ...
# Yacolt            16.0
# Yakima            21.0
# Yarrow Point      30.0
# Yelm              21.0
# Zillah             0.0
# Name: Electric Range, Length: 683, dtype: float64

# %%
agg_results = df1['Electric Range'].agg(['min', 'max', 'median', 'sum'])
print(agg_results)
# Out:
# min              0.0
# max            337.0
# median           0.0
# sum       10653224.0
# Name: Electric Range, dtype: float64

# %%
agg_results = df2['Electric Range'].agg(['min', 'max', 'median', 'sum'])
print(agg_results)
# Out:
# min              0.0
# max            337.0
# median          18.0
# sum       10214393.0
# Name: Electric Range, dtype: float64

# %%
df1_queried = df1.query("`Electric Range` > 100 and `Electric Range` < 200")
display(df1_queried)
# Out:
#         VIN (1-10) County Name    City Name State  Postal Code  Model Year  \
# 18      1N4BZ0CP8H        King     Bellevue    WA      98007.0        2017
# 24      WBY8P2C51K        King      Seattle    WA      98112.0        2019
# 29      WP0AC2Y15L        King      Seattle    WA      98102.0        2020
# 54      1N4BZ0CP2H        King         Kent    WA      98042.0        2017
# 59      1N4BZ1CP3K      Yakima       Yakima    WA      98902.0        2019
# ...            ...         ...          ...   ...          ...         ...
# 191209  1N4BZ0CP7H      Chelan  Leavenworth    WA      98826.0        2017
# 191316  1N4AZ1CPXL    Thurston      Olympia    WA      98513.0        2020
# 191321  1N4BZ1CP9K     Whatcom     Ferndale    WA      98248.0        2019
# 191369  WBY7Z2C58J   Snohomish      Edmonds    WA      98026.0        2018
# 191372  WVWKR7AU2K        King      Redmond    WA      98053.0        2019
#
#               Make   Model           Electric Vehicle Type  \
# ...

# %%
df1_queried = df1.query("`Electric Range` > 100 and `Electric Range` < 200")
display(df1_queried)
# Out:
#         VIN (1-10) County Name    City Name State  Postal Code  Model Year  \
# 18      1N4BZ0CP8H        King     Bellevue    WA      98007.0        2017
# 24      WBY8P2C51K        King      Seattle    WA      98112.0        2019
# 29      WP0AC2Y15L        King      Seattle    WA      98102.0        2020
# 54      1N4BZ0CP2H        King         Kent    WA      98042.0        2017
# 59      1N4BZ1CP3K      Yakima       Yakima    WA      98902.0        2019
# ...            ...         ...          ...   ...          ...         ...
# 191209  1N4BZ0CP7H      Chelan  Leavenworth    WA      98826.0        2017
# 191316  1N4AZ1CPXL    Thurston      Olympia    WA      98513.0        2020
# 191321  1N4BZ1CP9K     Whatcom     Ferndale    WA      98248.0        2019
# 191369  WBY7Z2C58J   Snohomish      Edmonds    WA      98026.0        2018
# 191372  WVWKR7AU2K        King      Redmond    WA      98053.0        2019
#
#               Make   Model           Electric Vehicle Type  \
# ...

# %%
df2_queried = df2.query("`Electric Range` > 100 and `Electric Range` < 200")
display(df2_queried)
# Out:
#         VIN (1-10) County Name          City Name State  Postal Code  \
# 23      2T3YL4DV5E        King            Seattle    WA      98108.0
# 28      WVWKR7AU0K        King           Kirkland    WA      98033.0
# 42      1N4BZ1CP2K        King             Renton    WA      98057.0
# 55      1N4AZ1CP3J      Island         Coupeville    WA      98239.0
# 61      1N4AZ1CP9L        King            Redmond    WA      98052.0
# ...            ...         ...                ...   ...          ...
# 150225  WVWPR7AU0K        King            Seattle    WA      98115.0
# 150243  1N4AZ1CP1L   Snohomish  Mountlake Terrace    WA      98043.0
# 150273  WBY8P4C52K   Jefferson      Port Townsend    WA      98368.0
# 150280  1N4AZ1CP4J     Spokane          Deer Park    WA      99006.0
# 150326  1N4BZ1CP6K        King             Vashon    WA      98070.0
#
#         Model Year        Make   Model  \
# 23            2014      TOYOTA    RAV4
# 28            2019  VOLKSWAGEN  E-GOLF
# ...

# %%
df1['Electric Range'] = df1['Electric Range'].apply(lambda x: round(x))

def averageScore(row):
    return row[['Electric Range']].mean()

df1_applied['Average'] = df1.apply(averageScore, axis=1)

display(df1_applied)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-d2675ab286be> in <cell line: 6>()
#       4     return row[['Electric Range']].mean()
#       5
# ----> 6 df1_applied['Average'] = df1.apply(averageScore, axis=1)
#       7
#       8 display(df1_applied)
#
# NameError: name 'df1_applied' is not defined

# %%
df2['Electric Range'] = df2['Electric Range'].apply(lambda x: round(x))

def averageScore(row):
    return row[['Electric Range', 'Base MSRP']].mean()

df2_applied = df2.apply(averageScore, axis=1)

display(df2_applied)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-c0b41af1136d> in <cell line: 1>()
# ----> 1 df2['Electric Range'] = df2['Electric Range'].apply(lambda x: round(x))
#       2
#       3 def averageScore(row):
#       4     return row[['Electric Range', 'Base MSRP']].mean()
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
def custom_round(x):
    if isinstance(x, (int, float)):
        if x < 1000:
            return round(x, -1)
        else:
            return round(x, -2)
    else:
        return x

df1_map = df1.applymap(custom_round)
df1_map

# %%
def custom_round(x):
    if isinstance(x, (int, float)):
        if x < 1000:
            return round(x, -1)
        else:
            return round(x, -2)
    else:
        return x

df2_map = df2.applymap(custom_round)
df2_map

# %%
pivoted_df2 = df2.pivot_table(index=['State'],
                       columns='City Name',
                       values=['Legislative District'])

pivoted_df2

# %%
pivoted_df1 = df1.pivot_table(index=['State'],
                       columns='City Name',
                       values=['Legislative District'])

pivoted_df1

# %%
missing_values1_copy = df1_copy.isnull().sum()
print(missing_values1_copy)
missing_values2_copy = df2_copy.isnull().sum()
print(missing_values2_copy)

# %%
columns_to_convert = ['Postal Code', 'Model Year', 'Electric Range', 'Base MSRP', 'Legislative District', 'DOL Vehicle ID']

for col in columns_to_convert:
    df1_copy[col] = pd.to_numeric(df1_copy[col], errors='coerce')
    df2_copy[col] = pd.to_numeric(df2_copy[col], errors='coerce')

imputer = SimpleImputer(strategy='constant', fill_value=0)
df1_imputed = pd.DataFrame(imputer.fit_transform(df1_copy[columns_to_convert]), columns=columns_to_convert)
df2_imputed = pd.DataFrame(imputer.fit_transform(df2_copy[columns_to_convert]), columns=columns_to_convert)

df1_copy[columns_to_convert] = df1_imputed.astype(int)
df2_copy[columns_to_convert] = df2_imputed.astype(int)

columns_to_add = ['County', 'City', 'State', 'Make', 'Model', 'Electric Vehicle Type', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Vehicle Location', 'Electric Utility']

imputer = SimpleImputer(strategy='constant', fill_value="Unknown")
df1_imputed = pd.DataFrame(imputer.fit_transform(df1_copy[columns_to_add]), columns=columns_to_add)
df2_imputed = pd.DataFrame(imputer.fit_transform(df2_copy[columns_to_add]), columns=columns_to_add)

df1_copy[columns_to_add] = df1_imputed
df2_copy[columns_to_add] = df2_imputed

# %%
missing_values1_copy = df1_copy.isnull().sum()
print(missing_values1_copy)
missing_values2_copy = df2_copy.isnull().sum()
print(missing_values2_copy)
